# %%
import pandas as pd

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
#encoding - 한글 깨지지 않도록 설정
pd.read_csv("/content/gdrive/My Drive/도로교통공단_교통사고 정보_20200714.csv", encoding="cp949")
# Out:
#        발생년      발생년월일시 주야 요일  ...  발생위치X_UTMK  발생위치Y_UTMK          경도         위도
# 0     2019  2019010100  야  화  ...   1150507.0   1685987.0  129.152465  35.157884
# 1     2019  2019010103  야  화  ...    943018.0   1921233.0  126.857149  37.288292
# 2     2019  2019010116  주  화  ...   1100414.0   1739893.0  128.609230  35.650108
# 3     2019  2019010119  야  화  ...    989194.0   1817621.0  127.379560  36.355946
# 4     2019  2019010121  야  화  ...   1127700.0   1767912.0  128.915041  35.899506
# ...    ...         ... .. ..  ...         ...         ...         ...        ...
# 3228  2019  2019123105  야  화  ...    964440.0   1943029.0  127.097769  37.485819
# 3229  2019  2019123108  주  화  ...   1097892.0   2009288.0  128.616149  38.078411
# 3230  2019  2019123112  주  화  ...   1082569.9   1777238.5  128.415998  35.988434
# 3231  2019  2019123112  주  화  ...   1157722.0   1731868.0  129.240504  35.570292
# 3232  2019  2019123116  주  화  ...   1098444.0   1693616.0  128.581874  35.233112
#
# ...

# %%
"""
# Mac 기준
# %mv /Users/~~~/~~~/도로교통공단_교통사고다발지역_20191010.csv .
pd.read_csv("도로교통공단_교통사고다발지역_20191010.csv", encoding="cp949")

# window 기준
# !move C:\Project\data.csv "C:\Users\name\Untitled Folder\data\도로교통공단_교통사고 정보_20200714.csv"

"""
